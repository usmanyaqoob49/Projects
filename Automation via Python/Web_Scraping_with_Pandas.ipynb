# %%
# !pip install pandas

# %%
import pandas as pd

# %%
#will return list of all tables in the website
NBA_Final = pd.read_html('https://en.wikipedia.org/wiki/NBA_Finals')

# %%
#no of tables
len(NBA_Final)
# Out:
# 27

# %%
NBA_Final[1]
# Out:
#     No.                                              Team   W   L   Win%  \
# 0    32                    Minneapolis/Los Angeles Lakers  17  15  0.531
# 1    22                                    Boston Celtics  17   5  0.773
# 2    12  Philadelphia/San Francisco/Golden State Warriors   7   5  0.583
# 3     9             Syracuse Nationals/Philadelphia 76ers   3   6  0.333
# 4     8                                   New York Knicks   2   6  0.250
# 5     7                        Fort Wayne/Detroit Pistons   3   4  0.429
# 6     6                                     Chicago Bulls   6   0  1.000
# 7     6                                        Miami Heat   3   3  0.500
# 8     6                                 San Antonio Spurs   5   1  0.833
# 9     5                               Cleveland Cavaliers   1   4  0.200
# 10    4                                   Houston Rockets   2   2  0.500
# 11    4                           St. Louis/Atlanta Hawks   1   3  0.250
# ...

# %% [markdown]
# # Reading .csv files from websites

# %%
#getting a cdv file from website
df_laliga21 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2122/SP1.csv')

# %%
#showing the above dataframe
df_laliga21
# Out:
#      Div        Date   Time   HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    SP1  13/08/2021  20:00   Valencia       Getafe     1     0   H     1
# 1    SP1  14/08/2021  18:30      Cadiz      Levante     1     1   D     0
# 2    SP1  14/08/2021  18:30   Mallorca        Betis     1     1   D     1
# 3    SP1  14/08/2021  21:00     Alaves  Real Madrid     1     4   A     0
# 4    SP1  14/08/2021  21:00    Osasuna      Espanol     0     0   D     0
# ..   ...         ...    ...        ...          ...   ...   ...  ..   ...
# 375  SP1  22/05/2022  19:00    Granada      Espanol     0     0   D     0
# 376  SP1  22/05/2022  19:00    Osasuna     Mallorca     0     2   A     0
# 377  SP1  22/05/2022  21:00  Barcelona   Villarreal     0     2   A     0
# 378  SP1  22/05/2022  21:00    Sevilla   Ath Bilbao     1     0   H     0
# 379  SP1  22/05/2022  21:00   Sociedad   Ath Madrid     1     2   A     0
#
#      HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# ...

# %%
#renaming columns
                            #old     #new name
df_laliga21.rename(columns={'FTHG': 'HomeGoals',
                            'FTAG': 'AwayGoals'}, inplace = True)

# %%
df_laliga21
# Out:
#      Div        Date   Time   HomeTeam     AwayTeam  HomeGoals  AwayGoals FTR  \
# 0    SP1  13/08/2021  20:00   Valencia       Getafe          1          0   H
# 1    SP1  14/08/2021  18:30      Cadiz      Levante          1          1   D
# 2    SP1  14/08/2021  18:30   Mallorca        Betis          1          1   D
# 3    SP1  14/08/2021  21:00     Alaves  Real Madrid          1          4   A
# 4    SP1  14/08/2021  21:00    Osasuna      Espanol          0          0   D
# ..   ...         ...    ...        ...          ...        ...        ...  ..
# 375  SP1  22/05/2022  19:00    Granada      Espanol          0          0   D
# 376  SP1  22/05/2022  19:00    Osasuna     Mallorca          0          2   A
# 377  SP1  22/05/2022  21:00  Barcelona   Villarreal          0          2   A
# 378  SP1  22/05/2022  21:00    Sevilla   Ath Bilbao          1          0   H
# 379  SP1  22/05/2022  21:00   Sociedad   Ath Madrid          1          2   A
#
# ...
